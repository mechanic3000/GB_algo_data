# %% [markdown]
# #### Урок 4. ДЗ ####
#
# 1. В коде из методички реализуйте один или несколько из критериев останова (количество листьев, количество используемых признаков, глубина дерева и т.д.)

# %%
import matplotlib.pyplot as plt
import random

from matplotlib.colors import ListedColormap
from sklearn.datasets import make_classification, make_circles
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.metrics import accuracy_score

import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
# сгенерируем данные
classification_data, classification_labels = make_classification(n_features=2, n_informative=2, 
                                                                 n_classes=2, n_redundant=0,
                                                                 n_clusters_per_class=1, random_state=5)
# classification_data, classification_labels = make_circles(n_samples=30, random_state=5)

# %%
# визуализируем сгенерированные данные

colors = ListedColormap(['red', 'blue'])
light_colors = ListedColormap(['lightcoral', 'lightblue'])

plt.figure(figsize=(8,8))
plt.scatter(list(map(lambda x: x[0], classification_data)), list(map(lambda x: x[1], classification_data)), 
              c=classification_labels, cmap=colors);

# %%
# Реализуем класс узла

class Node:
    
    def __init__(self, index, t, true_branch, false_branch):
        self.index = index  # индекс признака, по которому ведется сравнение с порогом в этом узле
        self.t = t  # значение порога
        self.true_branch = true_branch  # поддерево, удовлетворяющее условию в узле
        self.false_branch = false_branch  # поддерево, не удовлетворяющее условию в узле

# %%
# И класс терминального узла (листа)

class Leaf:
    
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels
        self.prediction = self.predict()
        
    def predict(self):
        # подсчет количества объектов разных классов
        classes = {}  # сформируем словарь "класс: количество объектов"
        for label in self.labels:
            if label not in classes:
                classes[label] = 0
            classes[label] += 1

        # найдем класс, количество объектов которого будет максимальным в этом листе и вернем его    
        prediction = max(classes, key=classes.get)

        return prediction

# %% [markdown]
# $$H(X) = \sum^{K}_{k=1}p_{k}(1-p_{k}) = 1 - \sum_{k=1}^K{p_k^2} ,$$

# %%
# Расчет критерия Джини

def gini(labels):
    #  подсчет количества объектов разных классов
    classes = {}
    for label in labels:
        if label not in classes:
            classes[label] = 0
        classes[label] += 1
    
    #  расчет критерия
    impurity = 1
    for label in classes:
        p = classes[label] / len(labels)
        impurity -= p ** 2
        
    return impurity

# %% [markdown]
# $$H(X_{m}) - \frac{|X_{l}|}{|X_{m}|}H(X_{l}) - \frac{|X_{r}|}{|X_{m}|}H(X_{r}),$$

# %%
# Расчет прироста

def gain(left_labels, right_labels, root_gini):

    # доля выборки, ушедшая в левое поддерево
    p = float(left_labels.shape[0]) / (left_labels.shape[0] + right_labels.shape[0])
    
    return root_gini - p * gini(left_labels) - (1 - p) * gini(right_labels)

# %%
# Разбиение датасета в узле

def split(data, labels, column_index, t):
    
    left = np.where(data[:, column_index] <= t)
    right = np.where(data[:, column_index] > t)
        
    true_data = data[left]
    false_data = data[right]
    
    true_labels = labels[left]
    false_labels = labels[right]
        
    return true_data, false_data, true_labels, false_labels

# %%
# Нахождение наилучшего разбиения

def find_best_split(data, labels):
    
    #  обозначим минимальное количество объектов в узле
    min_samples_leaf = 3

    root_gini = gini(labels)

    best_gain = 0
    best_t = None
    best_index = None
    
    n_features = data.shape[1]
    
    for index in range(n_features):
        # будем проверять только уникальные значения признака, исключая повторения
        t_values = np.unique(data[:, index])
        
        for t in t_values:
            true_data, false_data, true_labels, false_labels = split(data, labels, index, t)
            #  пропускаем разбиения, в которых в узле остается менее 5 объектов
            if len(true_data) < min_samples_leaf or len(false_data) < min_samples_leaf:
                continue
            
            current_gain = gain(true_labels, false_labels, root_gini)
            
            #  выбираем порог, на котором получается максимальный прирост качества
            if current_gain > best_gain:
                best_gain, best_t, best_index = current_gain, t, index

    return best_gain, best_t, best_index

# %%
import time
# Построение дерева с помощью рекурсивной функции

# ==============================
#РЕШЕНИЕ ограничение глубины дерева (добавлены параметры max_deep, curr_max_deep)
# ==============================

def build_tree(data, labels, max_deep=np.inf, curr_max_deep=0):

    gain, t, index = find_best_split(data, labels)

    #  Базовый случай - прекращаем рекурсию, когда нет прироста в качества
    if gain == 0:
        return Leaf(data, labels)
    
    # Прекращаем рекурсию при достижении максимальной глубины дерева
    if max_deep <= curr_max_deep:
        return Leaf(data, labels)

    true_data, false_data, true_labels, false_labels = split(data, labels, index, t)

    curr_max_deep += 1 #следующая глубина дерева
    
    # Рекурсивно строим два поддерева
    true_branch = build_tree(true_data, true_labels, max_deep, curr_max_deep)

#     print(time.time(), true_branch)
    false_branch = build_tree(false_data, false_labels, max_deep, curr_max_deep)
    
#     print(time.time(), false_branch)
    
    # Возвращаем класс узла со всеми поддеревьями, то есть целого дерева
    return Node(index, t, true_branch, false_branch)

# %%
def classify_object(obj, node):

    #  Останавливаем рекурсию, если достигли листа
    if isinstance(node, Leaf):
        answer = node.prediction

        return answer

    if obj[node.index] <= node.t:
        return classify_object(obj, node.true_branch)
    else:
        return classify_object(obj, node.false_branch)

# %%
def predict(data, tree):
    
    classes = []
    for obj in data:
        prediction = classify_object(obj, tree)
        classes.append(prediction)
    return classes

# %%
# Разобьем выборку на обучающую и тестовую

from sklearn.model_selection import train_test_split

train_data, test_data, train_labels, test_labels = train_test_split(classification_data, 
                                                                    classification_labels, 
                                                                    test_size=0.3,
                                                                    random_state=1)

# %%
# Построим дерево по обучающей выборке
max_deep = 3
my_tree = build_tree(train_data, train_labels, max_deep)

# %%
# Напечатаем ход нашего дерева
def print_tree(node, spacing=""):

    # Если лист, то выводим его прогноз
    if isinstance(node, Leaf):
        print(spacing + "Прогноз:", node.prediction)
        return

    # Выведем значение индекса и порога на этом узле
    print(spacing + 'Индекс', str(node.index), '<=', str(node.t))

    # Рекурсионный вызов функции на положительном поддереве
    print(spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Рекурсионный вызов функции на отрицательном поддереве
    print(spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")
    
print_tree(my_tree)
# Out:
# Индекс 0 <= 0.16261402870113306
# --> True:
#   Индекс 1 <= -1.5208896621663803
#   --> True:
#     Индекс 0 <= -0.9478301462477035
#     --> True:
#       Прогноз: 0
#     --> False:
#       Прогноз: 1
#   --> False:
#     Прогноз: 0
# --> False:
#   Прогноз: 1

# %%
# Получим ответы для обучающей выборки 
train_answers = predict(train_data, my_tree)

# %%
# И получим ответы для тестовой выборки
answers = predict(test_data, my_tree)

# %%
# Введем функцию подсчета точности как доли правильных ответов
def accuracy_metric(actual, predicted):
    correct = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            correct += 1
    return correct / float(len(actual)) * 100.0

# %%
# Точность на обучающей выборке
train_accuracy = accuracy_metric(train_labels, train_answers)
train_accuracy
# Out:
# 98.57142857142858

# %%
# Точность на тестовой выборке
test_accuracy = accuracy_metric(test_labels, answers)
test_accuracy
# Out:
# 100.0

# %%
# Визуализируем дерево на графике

def get_meshgrid(data, step=.05, border=1.2):
    x_min, x_max = data[:, 0].min() - border, data[:, 0].max() + border
    y_min, y_max = data[:, 1].min() - border, data[:, 1].max() + border
    return np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))


def visualize(train_data, test_data):
    plt.figure(figsize = (16, 7))

    # график обучающей выборки
    plt.subplot(1,2,1)
    xx, yy = get_meshgrid(train_data)
    mesh_predictions = np.array(predict(np.c_[xx.ravel(), yy.ravel()], my_tree)).reshape(xx.shape)
    plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
    plt.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, cmap = colors)
    plt.title(f'Train accuracy={train_accuracy:.2f}')

    # график тестовой выборки
    plt.subplot(1,2,2)
    plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
    plt.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, cmap = colors)
    plt.title(f'Test accuracy={test_accuracy:.2f}')

# %%
visualize(train_data, test_data)

# %%
df_full = pd.read_csv('./data/cardio.csv', sep=';')

features = ['age', 'height']
target = ['cardio']

df = df_full[features + target]
print(df.shape)

train_data, test_data, train_labels, test_labels = train_test_split(df[features].values, 
                                                                    np.squeeze(df[target].values),
                                                                    test_size=0.3,
                                                                    random_state=1)
# Out:
# (70000, 3)

# %%
# %%time
max_deep = 3
my_tree = build_tree(train_data, train_labels, max_deep)
# Out:
# CPU times: user 5.14 s, sys: 31.6 ms, total: 5.18 s
# Wall time: 5.21 s

# %%
print_tree(my_tree)
# Out:
# Индекс 0 <= 54
# --> True:
#   Индекс 0 <= 44
#   --> True:
#     Индекс 0 <= 40
#     --> True:
#       Прогноз: 0
#     --> False:
#       Прогноз: 0
#   --> False:
#     Индекс 0 <= 50
#     --> True:
#       Прогноз: 0
#     --> False:
#       Прогноз: 0
# --> False:
#   Индекс 0 <= 60
#   --> True:
#     Индекс 0 <= 58
#     --> True:
#       Прогноз: 1
#     --> False:
#       Прогноз: 1
#   --> False:
#     Индекс 0 <= 62
#     --> True:
#       Прогноз: 1
#     --> False:
#       Прогноз: 1

# %%
train_answers = predict(train_data, my_tree)
test_answers = predict(test_data, my_tree)

# %%
train_accuracy = accuracy_metric(train_labels, train_answers)
test_accuracy = accuracy_metric(test_labels, test_answers)

print(f'Train accuracy', train_accuracy)
print(f'Test accuracy', test_accuracy)
# Out:
# Train accuracy 59.80408163265306
# Test accuracy 59.69523809523809

# %%
# %%time
visualize(train_data, test_data)
# Out:
# CPU times: user 4 s, sys: 98.5 ms, total: 4.09 s
# Wall time: 4.12 s

# %%
dt = DecisionTreeClassifier()
dt.fit(train_data, train_labels)

train_answers = dt.predict(train_data)
test_answers = dt.predict(test_data)

train_accuracy = accuracy_metric(train_labels, train_answers)
test_accuracy = accuracy_metric(test_labels, test_answers)

print(f'Train accuracy', train_accuracy)
print(f'Test accuracy', test_accuracy)
# Out:
# Train accuracy 61.559183673469384
# Test accuracy 58.352380952380955

# %%
accuracy_score(train_answers, train_labels) * 100
# Out:
# 61.559183673469384

# %% [markdown]
# <hr>
#
# 2. *Реализуйте дерево для задачи регрессии. Возьмите за основу дерево, реализованное в методичке, заменив механизм предсказания в листе на взятие среднего значения по выборке, и критерий Джини на дисперсию значений.

# %%
# И класс терминального узла (листа)

class Leaf:
    
    def __init__(self, data, target):
        self.data = data
        self.target = target
        self.prediction = self.predict()
        
    def predict(self):
        return np.mean(self.target)

# %%
def calc_mse(target):
    return np.mean((target - np.mean(target))**2)

# %%
# Расчет прироста

def gain(left_labels, right_labels, root_mse):
  
    n_total = left_labels.shape[0] + right_labels.shape[0]
    
    return root_mse - (left_labels.shape[0] * calc_mse(left_labels) / n_total + 
                        right_labels.shape[0] * calc_mse(right_labels) / n_total)

# %%
# Нахождение наилучшего разбиения (регрессия)

def find_best_split(data, target):
    
    #  обозначим минимальное количество объектов в узле
    min_samples_leaf = 3
    
    root_mse = calc_mse(target)

    best_gain = 0
    best_t = None
    best_index = None
    
    n_features = data.shape[1]
    
    for index in range(n_features):
        # будем проверять только уникальные значения признака, исключая повторения
        t_values = np.unique(data[:, index])
        
        for t in t_values:
            true_data, false_data, true_target, false_target = split(data, target, index, t)
            #  пропускаем разбиения, в которых в узле остается менее 5 объектов
            if len(true_data) < min_samples_leaf or len(false_data) < min_samples_leaf:
                continue
            
            current_gain = gain(true_target, false_target, root_mse)

            #  выбираем порог, на котором получается максимальный прирост качества
            if current_gain > best_gain:
                best_gain, best_t, best_index = current_gain, t, index

    return best_gain, best_t, best_index

# %%
import time
# Построение дерева с помощью рекурсивной функции

# ==============================
#РЕШЕНИЕ ограничение глубины дерева (добавлены параметры max_deep, curr_max_deep)
# ==============================

def build_tree(data, target, max_deep=np.inf, curr_max_deep=0):

    gain, t, index = find_best_split(data, target)

    #  Базовый случай - прекращаем рекурсию, когда нет прироста в качества
    if gain == 0:
        return Leaf(data, target)
    
    # Прекращаем рекурсию при достижении максимальной глубины дерева
    if max_deep <= curr_max_deep:
        return Leaf(data, target)

    true_data, false_data, true_target, false_target = split(data, target, index, t)

    curr_max_deep += 1 #следующая глубина дерева
    
    # Рекурсивно строим два поддерева
    true_branch = build_tree(true_data, true_target, max_deep, curr_max_deep)

#     print(time.time(), true_branch)
    false_branch = build_tree(false_data, false_target, max_deep, curr_max_deep)
    
#     print(time.time(), false_branch)
    
    # Возвращаем класс узла со всеми поддеревьями, то есть целого дерева
    return Node(index, t, true_branch, false_branch)

# %%
df_full_regression = pd.read_csv('./data/cardio.csv', sep=';')

features = ['height', 'cardio']
target = ['age']

df = df_full[features + target]
print(df.shape)

train_data, test_data, train_target, test_target = train_test_split(df[features].values, 
                                                                    np.squeeze(df[target].values),
                                                                    test_size=0.3,
                                                                    random_state=1)
# Out:
# (70000, 3)

# %%
# %%time
my_tree = build_tree(train_data, train_target)
# Out:
# CPU times: user 488 ms, sys: 15 ms, total: 503 ms
# Wall time: 511 ms

# %%
print_tree(my_tree)
# Out:
# Индекс 1 <= 0
# --> True:
#   Индекс 0 <= 158
#   --> True:
#     Индекс 0 <= 149
#     --> True:
#       Индекс 0 <= 142
#       --> True:
#         Индекс 0 <= 70
#         --> True:
#           Индекс 0 <= 65
#           --> True:
#             Прогноз: 52.8
#           --> False:
#             Прогноз: 43.6
#         --> False:
#           Индекс 0 <= 76
#           --> True:
#             Прогноз: 61.0
#           --> False:
#             Индекс 0 <= 110
#             --> True:
#               Индекс 0 <= 99
#               --> True:
#                 Прогноз: 50.0
#               --> False:
#                 Прогноз: 43.25
#             --> False:
#               Индекс 0 <= 141
#               --> True:
#                 Индекс 0 <= 138
#                 --> True:
#                   Индекс 0 <= 136
#                   --> True:
#                     Индекс 0 <= 128
#                     --> True:
#                       Индекс 0 <= 120
#                       --> True:
#                         Прогноз: 49.76923076923077
#                       --> False:
#                         Прогноз: 49.0
#                     --> False:
#                       Индекс 0 <= 130
#                       --> True:
#                         Прогноз: 57.5
#                       --> False:
#                         Индекс 0 <= 135
#                         --> True:
#                           Индекс 0 <= 133
#                           --> True:
#                             Прогноз: 51.0
#                           --> False:
#                             Прогноз: 47.333333333333336
#                         --> False:
#                           Прогноз: 53.666666666666664
#                   --> False:
#                     Индекс 0 <= 137
#                     --> True:
#                       Прогноз: 47.8
#                     --> False:
#                       Прогноз: 43.666666666666664
#                 --> False:
#                   Прогноз: 52.529411764705884
#               --> False:
#                 Прогноз: 48.77777777777778
#       --> False:
#         Индекс 0 <= 147
#         --> True:
#           Индекс 0 <= 144
#           --> True:
#             Индекс 0 <= 143
#             --> True:
#               Прогноз: 54.54545454545455
#             --> False:
#               Прогноз: 56.22222222222222
#           --> False:
#             Индекс 0 <= 145
#             --> True:
#               Прогноз: 52.8936170212766
#             --> False:
#               Индекс 0 <= 146
#               --> True:
#                 Прогноз: 54.270833333333336
#               --> False:
#                 Прогноз: 54.215053763440864
#         --> False:
#           Индекс 0 <= 148
#           --> True:
#             Прогноз: 53.247058823529414
#           --> False:
#             Прогноз: 52.78378378378378
#     --> False:
#       Индекс 0 <= 156
#       --> True:
#         Индекс 0 <= 154
#         --> True:
#           Индекс 0 <= 153
#           --> True:
#             Индекс 0 <= 150
#             --> True:
#               Прогноз: 51.78034682080925
#             --> False:
#               Индекс 0 <= 151
#               --> True:
#                 Прогноз: 52.009803921568626
#               --> False:
#                 Индекс 0 <= 152
#                 --> True:
#                   Прогноз: 51.80759493670886
#                 --> False:
#                   Прогноз: 51.88135593220339
#           --> False:
#             Прогноз: 52.116
#         --> False:
#           Индекс 0 <= 155
#           --> True:
#             Прогноз: 51.75540765391015
#           --> False:
#             Прогноз: 51.804134929270944
#       --> False:
#         Индекс 0 <= 157
#         --> True:
#           Прогноз: 51.39685039370079
#         --> False:
#           Прогноз: 51.56480686695279
#   --> False:
#     Индекс 0 <= 174
#     --> True:
#       Индекс 0 <= 165
#       --> True:
#         Индекс 0 <= 163
#         --> True:
#           Индекс 0 <= 162
#           --> True:
#             Индекс 0 <= 160
#             --> True:
#               Индекс 0 <= 159
#               --> True:
#                 Прогноз: 51.08196721311475
#               --> False:
#                 Прогноз: 51.51379310344828
#             --> False:
#               Индекс 0 <= 161
#               --> True:
#                 Прогноз: 51.189419795221845
#               --> False:
#                 Прогноз: 51.155364806866956
#           --> False:
#             Прогноз: 50.77052868391451
#         --> False:
#           Индекс 0 <= 164
#           --> True:
#             Прогноз: 51.5935098206661
#           --> False:
#             Прогноз: 51.40315838365072
#       --> False:
#         Индекс 0 <= 173
#         --> True:
#           Индекс 0 <= 170
#           --> True:
#             Индекс 0 <= 167
#             --> True:
#               Индекс 0 <= 166
#               --> True:
#                 Прогноз: 50.911554921540656
#               --> False:
#                 Прогноз: 50.89059080962801
#             --> False:
#               Индекс 0 <= 168
#               --> True:
#                 Прогноз: 50.99936948297604
#               --> False:
#                 Индекс 0 <= 169
#                 --> True:
#                   Прогноз: 51.17936354869817
#                 --> False:
#                   Прогноз: 51.01045903544451
#           --> False:
#             Индекс 0 <= 171
#             --> True:
#               Прогноз: 50.562899786780385
#             --> False:
#               Индекс 0 <= 172
#               --> True:
#                 Прогноз: 50.881188118811885
#               --> False:
#                 Прогноз: 51.01907356948229
#         --> False:
#           Прогноз: 51.530141843971634
#     --> False:
#       Индекс 0 <= 189
#       --> True:
#         Индекс 0 <= 178
#         --> True:
#           Индекс 0 <= 177
#           --> True:
#             Индекс 0 <= 176
#             --> True:
#               Индекс 0 <= 175
#               --> True:
#                 Прогноз: 50.23875968992248
#               --> False:
#                 Прогноз: 50.28238341968912
#             --> False:
#               Прогноз: 50.03472222222222
#           --> False:
#             Прогноз: 50.303030303030305
#         --> False:
#           Индекс 0 <= 184
#           --> True:
#             Индекс 0 <= 183
#             --> True:
#               Индекс 0 <= 180
#               --> True:
#                 Индекс 0 <= 179
#                 --> True:
#                   Прогноз: 50.91139240506329
#                 --> False:
#                   Прогноз: 50.729032258064514
#               --> False:
#                 Индекс 0 <= 181
#                 --> True:
#                   Прогноз: 49.371428571428574
#                 --> False:
#                   Индекс 0 <= 182
#                   --> True:
#                     Прогноз: 50.656565656565654
#                   --> False:
#                     Прогноз: 50.07272727272727
#             --> False:
#               Прогноз: 51.784615384615385
#           --> False:
#             Индекс 0 <= 186
#             --> True:
#               Индекс 0 <= 185
#               --> True:
#                 Прогноз: 49.47674418604651
#               --> False:
#                 Прогноз: 49.75555555555555
#             --> False:
#               Индекс 0 <= 187
#               --> True:
#                 Прогноз: 51.28125
#               --> False:
#                 Индекс 0 <= 188
#                 --> True:
#                   Прогноз: 50.588235294117645
#                 --> False:
#                   Прогноз: 51.0
#       --> False:
#         Индекс 0 <= 190
#         --> True:
#           Прогноз: 54.3
#         --> False:
#           Индекс 0 <= 193
#           --> True:
#             Индекс 0 <= 192
#             --> True:
#               Индекс 0 <= 191
#               --> True:
#                 Прогноз: 51.666666666666664
#               --> False:
#                 Прогноз: 50.75
#             --> False:
#               Прогноз: 54.5
#           --> False:
#             Индекс 0 <= 197
#             --> True:
#               Прогноз: 49.5
#             --> False:
#               Прогноз: 51.75
# --> False:
#   Индекс 0 <= 158
#   --> True:
#     Индекс 0 <= 151
#     --> True:
#       Индекс 0 <= 132
#       --> True:
#         Индекс 0 <= 122
#         --> True:
#           Индекс 0 <= 97
#           --> True:
#             Индекс 0 <= 67
#             --> True:
#               Прогноз: 56.25
#             --> False:
#               Прогноз: 48.4
#           --> False:
#             Индекс 0 <= 110
#             --> True:
#               Прогноз: 55.8
#             --> False:
#               Прогноз: 54.583333333333336
#         --> False:
#           Прогноз: 50.5
#       --> False:
#         Индекс 0 <= 149
#         --> True:
#           Индекс 0 <= 148
#           --> True:
#             Индекс 0 <= 139
#             --> True:
#               Индекс 0 <= 136
#               --> True:
#                 Прогноз: 55.5
#               --> False:
#                 Индекс 0 <= 137
#                 --> True:
#                   Прогноз: 58.25
#                 --> False:
#                   Прогноз: 60.333333333333336
#             --> False:
#               Индекс 0 <= 140
#               --> True:
#                 Прогноз: 54.68181818181818
#               --> False:
#                 Индекс 0 <= 142
#                 --> True:
#                   Индекс 0 <= 141
#                   --> True:
#                     Прогноз: 58.333333333333336
#                   --> False:
#                     Прогноз: 57.90909090909091
#                 --> False:
#                   Индекс 0 <= 143
#                   --> True:
#                     Прогноз: 55.72222222222222
#                   --> False:
#                     Индекс 0 <= 145
#                     --> True:
#                       Индекс 0 <= 144
#                       --> True:
#                         Прогноз: 57.464285714285715
#                       --> False:
#                         Прогноз: 57.016949152542374
#                     --> False:
#                       Индекс 0 <= 147
#                       --> True:
#                         Индекс 0 <= 146
#                         --> True:
#                           Прогноз: 56.21818181818182
#                         --> False:
#                           Прогноз: 56.3421052631579
#                       --> False:
#                         Прогноз: 56.93162393162393
#           --> False:
#             Прогноз: 57.390243902439025
#         --> False:
#           Индекс 0 <= 150
#           --> True:
#             Прогноз: 56.361477572559366
#           --> False:
#             Прогноз: 56.18181818181818
#     --> False:
#       Индекс 0 <= 156
#       --> True:
#         Индекс 0 <= 152
#         --> True:
#           Прогноз: 55.758865248226954
#         --> False:
#           Индекс 0 <= 155
#           --> True:
#             Индекс 0 <= 154
#             --> True:
#               Индекс 0 <= 153
#               --> True:
#                 Прогноз: 55.40659340659341
#               --> False:
#                 Прогноз: 55.56923076923077
#             --> False:
#               Прогноз: 55.14877300613497
#           --> False:
#             Прогноз: 55.512474012474016
#       --> False:
#         Индекс 0 <= 157
#         --> True:
#           Прогноз: 55.110410094637224
#         --> False:
#           Прогноз: 55.119555935098205
#   --> False:
#     Индекс 0 <= 170
#     --> True:
#       Индекс 0 <= 169
#       --> True:
#         Индекс 0 <= 166
#         --> True:
#           Индекс 0 <= 162
#           --> True:
#             Индекс 0 <= 160
#             --> True:
#               Индекс 0 <= 159
#               --> True:
#                 Прогноз: 54.31881804043546
#               --> False:
#                 Прогноз: 54.3737780333525
#             --> False:
#               Индекс 0 <= 161
#               --> True:
#                 Прогноз: 54.317324185248715
#               --> False:
#                 Прогноз: 54.27616534740545
#           --> False:
#             Индекс 0 <= 163
#             --> True:
#               Прогноз: 54.67640449438202
#             --> False:
#               Индекс 0 <= 164
#               --> True:
#                 Прогноз: 54.48602878916173
#               --> False:
#                 Индекс 0 <= 165
#                 --> True:
#                   Прогноз: 54.35965794768612
#                 --> False:
#                   Прогноз: 54.411764705882355
#         --> False:
#           Индекс 0 <= 167
#           --> True:
#             Прогноз: 54.07620164126612
#           --> False:
#             Индекс 0 <= 168
#             --> True:
#               Прогноз: 54.42494996664443
#             --> False:
#               Прогноз: 54.345549738219894
#       --> False:
#         Прогноз: 54.115796098174954
#     --> False:
#       Индекс 0 <= 182
#       --> True:
#         Индекс 0 <= 173
#         --> True:
#           Индекс 0 <= 171
#           --> True:
#             Прогноз: 53.82067510548523
#           --> False:
#             Индекс 0 <= 172
#             --> True:
#               Прогноз: 53.68260869565217
#             --> False:
#               Прогноз: 53.67430025445292
#         --> False:
#           Индекс 0 <= 174
#           --> True:
#             Прогноз: 52.93181818181818
#           --> False:
#             Индекс 0 <= 180
#             --> True:
#               Индекс 0 <= 178
#               --> True:
#                 Индекс 0 <= 177
#                 --> True:
#                   Индекс 0 <= 175
#                   --> True:
#                     Прогноз: 53.37190082644628
#                   --> False:
#                     Индекс 0 <= 176
#                     --> True:
#                       Прогноз: 53.73170731707317
#                     --> False:
#                       Прогноз: 53.449438202247194
#                 --> False:
#                   Прогноз: 53.206593406593406
#               --> False:
#                 Индекс 0 <= 179
#                 --> True:
#                   Прогноз: 54.42857142857143
#                 --> False:
#                   Прогноз: 53.872964169381106
#             --> False:
#               Индекс 0 <= 181
#               --> True:
#                 Прогноз: 52.46875
#               --> False:
#                 Прогноз: 53.278688524590166
#       --> False:
#         Индекс 0 <= 188
#         --> True:
#           Индекс 0 <= 187
#           --> True:
#             Индекс 0 <= 183
#             --> True:
#               Прогноз: 51.6078431372549
#             --> False:
#               Индекс 0 <= 184
#               --> True:
#                 Прогноз: 52.81481481481482
#               --> False:
#                 Индекс 0 <= 185
#                 --> True:
#                   Прогноз: 52.18292682926829
#                 --> False:
#                   Индекс 0 <= 186
#                   --> True:
#                     Прогноз: 51.729729729729726
#                   --> False:
#                     Прогноз: 52.064516129032256
#           --> False:
#             Прогноз: 55.0
#         --> False:
#           Индекс 0 <= 196
#           --> True:
#             Индекс 0 <= 189
#             --> True:
#               Прогноз: 47.76923076923077
#             --> False:
#               Индекс 0 <= 190
#               --> True:
#                 Прогноз: 51.6875
#               --> False:
#                 Индекс 0 <= 192
#                 --> True:
#                   Индекс 0 <= 191
#                   --> True:
#                     Прогноз: 48.333333333333336
#                   --> False:
#                     Прогноз: 50.75
#                 --> False:
#                   Прогноз: 48.0
#           --> False:
#             Индекс 0 <= 197
#             --> True:
#               Прогноз: 55.0
#             --> False:
#               Прогноз: 53.0

# %%
train_answers = predict(train_data, my_tree)
test_answers = predict(test_data, my_tree)

# %%
from sklearn.metrics import r2_score

train_r2 = r2_score(train_target, train_answers)
test_r2 = r2_score(test_target, test_answers)

train_r2, test_r2
# Out:
# (0.06838291728614398, 0.06308486122864254)
